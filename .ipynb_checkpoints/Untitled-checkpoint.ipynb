# %%
from __future__ import print_function
import os
data_path = ['data']

# %%
import pandas as pd

# Import the data using the file path
filepath = os.sep.join(data_path + ["youtubers_df.csv" ])
data = pd.read_csv('youtubers_df.csv')
data
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
data.head(1).T
# Out:
#                                                             0
# Rank                                                        1
# Username                                              tseries
# Categories                                     Música y baile
# Suscribers                                        249500000.0
# Country                                                 India
# Visits                                                86200.0
# Likes                                                  2700.0
# Comments                                                 78.0
# Links       http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...

# %%
# Remove extraneous columns
data.drop(['Categories', 'Country', 'Links'], axis=1, inplace=True)
data
# Out:
#      Rank              Username   Suscribers       Visits      Likes  Comments
# 0       1               tseries  249500000.0      86200.0     2700.0      78.0
# 1       2               MrBeast  183500000.0  117400000.0  5300000.0   18500.0
# 2       3             CoComelon  165500000.0    7000000.0    24700.0       0.0
# 3       4              SETIndia  162600000.0      15600.0      166.0       9.0
# 4       5         KidsDianaShow  113500000.0    3900000.0    12400.0       0.0
# ..    ...                   ...          ...          ...        ...       ...
# 995   996          hamzymukbang   11700000.0     397400.0    14000.0     124.0
# 996   997            Adaahqueen   11700000.0    1100000.0    92500.0     164.0
# 997   998  LittleAngelIndonesia   11700000.0     211400.0      745.0       0.0
# 998   999          PenMultiplex   11700000.0      14000.0       81.0       1.0
# 999  1000         OneindiaHindi   11700000.0       2200.0       31.0       1.0
#
# [1000 rows x 6 columns]

# %%
# Get a list of all the columns that don't contain the label
x_cols = [x for x in data.columns if x != 'Likes']

# Split the data into two dataframes
X_data = data[x_cols]
y_data = data['Likes']

# # alternatively:
# X_data = data.copy()
# y_data = X_data.pop('churned')
X_data
# Out:
#      Rank              Username   Suscribers       Visits  Comments
# 0       1               tseries  249500000.0      86200.0      78.0
# 1       2               MrBeast  183500000.0  117400000.0   18500.0
# 2       3             CoComelon  165500000.0    7000000.0       0.0
# 3       4              SETIndia  162600000.0      15600.0       9.0
# 4       5         KidsDianaShow  113500000.0    3900000.0       0.0
# ..    ...                   ...          ...          ...       ...
# 995   996          hamzymukbang   11700000.0     397400.0     124.0
# 996   997            Adaahqueen   11700000.0    1100000.0     164.0
# 997   998  LittleAngelIndonesia   11700000.0     211400.0       0.0
# 998   999          PenMultiplex   11700000.0      14000.0       1.0
# 999  1000         OneindiaHindi   11700000.0       2200.0       1.0
#
# [1000 rows x 5 columns]

# %%
# Get a list of all the columns that don't contain the label
x_cols = [x for x in data.columns if x != 'Username']

# Split the data into two dataframes
X_data = data[x_cols]
y_data = data['Username']

# # alternatively:
# X_data = data.copy()
# y_data = X_data.pop('churned')
y_data
# Out:
# 0                   tseries
# 1                   MrBeast
# 2                 CoComelon
# 3                  SETIndia
# 4             KidsDianaShow
#                ...
# 995            hamzymukbang
# 996              Adaahqueen
# 997    LittleAngelIndonesia
# 998            PenMultiplex
# 999           OneindiaHindi
# Name: Username, Length: 1000, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

knn = knn.fit(X_data, y_data)

y_pred = knn.predict(X_data) 
y_pred
# Out:
# array(['CoComelon', 'CoComelon', 'CoComelon', 'CoComelon',
#        'KidsDianaShow', 'KidsDianaShow', 'KidsDianaShow', 'VladandNiki',
#        'VladandNiki', 'VladandNiki', 'BLACKPINK', 'BLACKPINK',
#        '5MinuteCraftsYouTube', '5MinuteCraftsYouTube',
#        '5MinuteCraftsYouTube', 'HYBELABELS', 'HYBELABELS', 'ChuChuTV',
#        'ChuChuTV', 'KondZilla', 'KondZilla', 'KondZilla', 'MOVIECLIPS',
#        'ElReinoInfantil', 'ElReinoInfantil', 'ElReinoInfantil',
#        'ElReinoInfantil', 'ElReinoInfantil', 'SonyMusicIndia',
#        'SonyMusicIndia', 'SonyMusicIndia', 'LooLooKids', 'LooLooKids',
#        'LooLooKids', 'ArianaGrande', 'ArianaGrande', 'ArianaGrande',
#        'ArianaGrande', 'BillieEilish', 'BillieEilish', 'BillieEilish',
#        'BillieEilish', 'badabunOficial', 'A4a4a4a4', 'HarPalGeoOfficial',
#        'ARYDigitalasia', 'ARYDigitalasia', 'ARYDigitalasia', 'felipeneto',
#        'BRIGHTSIDEOFFICIAL', 'abscbnentertainment', 'BRIGHTSIDEOFFICIAL',
# ...

# %%
def accuracy(real, predict):
    return sum(y_data == y_pred) / float(real.shape[0])

# %%
print(accuracy(y_data, y_pred))
# Out:
# 0.345

# %%
knn = KNeighborsClassifier(n_neighbors=5, weights='distance')

knn = knn.fit(X_data, y_data)

y_pred = knn.predict(X_data)

print(accuracy(y_data, y_pred))
# Out:
# 0.997

# %%
score_list = list()

for k in range(1, 21):
    
    knn = KNeighborsClassifier(n_neighbors=k)
    knn = knn.fit(X_data, y_data)
    
    y_pred = knn.predict(X_data)
    score = accuracy(y_data, y_pred)
    
    score_list.append((k, score))
    
score_df = pd.DataFrame(score_list, columns=['k', 'accuracy'])
score_df
# Out:
#      k  accuracy
# 0    1     0.996
# 1    2     0.514
# 2    3     0.345
# 3    4     0.249
# 4    5     0.205
# 5    6     0.184
# 6    7     0.152
# 7    8     0.139
# 8    9     0.124
# 9   10     0.110
# 10  11     0.104
# 11  12     0.096
# 12  13     0.085
# 13  14     0.079
# 14  15     0.074
# 15  16     0.068
# 16  17     0.063
# 17  18     0.062
# 18  19     0.056
# 19  20     0.055

# %%
# Import libraries to make the plot

import matplotlib.pyplot as plt
import seaborn as sns

get_ipython().run_line_magic('matplotlib', 'inline')

# %%
sns.set_context('talk')
sns.set_style('ticks')
sns.set_palette('dark')

ax = score_df.set_index('k').plot()

ax.set(xlabel='k', ylabel='accuracy')
ax.set_xticks(range(1, 21));
